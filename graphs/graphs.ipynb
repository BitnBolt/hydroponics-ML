# %% [markdown]
# # Sensor timeline graphs (g1–g5)
#
# Plots **time vs value** graphs using data windows from `task_graphs/` and styling from `reference/reference.png` (dotted grid, bold title, reference colours).
#
# Run all cells to regenerate figures in `output_graphs/`.

# %%
# %matplotlib inline
from plot_graphs import main

main()
